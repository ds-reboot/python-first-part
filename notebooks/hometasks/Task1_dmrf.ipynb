# %% [markdown]
# # Задание
# * Собрать информацию о всех строящихся объектах на сайте "наш.дом.рф"
# * Cохранить ее в pandas dataframe
# * Cохранить pandas dataframe в excel
# * Cохранить pandas dataframe в pickle
# * Cохранить pandas dataframe в БД
#
# # Задание *
# * Написать скрипт, который скачивает фотографии всех строящихся объектов с сайта "наш.дом.рф"

# %%
import requests
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 import requests
#
# ModuleNotFoundError: No module named 'requests'

# %% [markdown]
# ## Список объектов

# %%
offset_ = 1
limit_ = 10000
url = f'https://xn--80az8a.xn--d1aqf.xn--p1ai/%D1%81%D0%B5%D1%80%D0%B2%D0%B8%D1%81%D1%8B/api/kn/object?offset={offset_}&limit={limit_}&sortField=devId.devShortCleanNm&sortType=asc&objStatus=0'
res = requests.get(url)
objects_data = res.json()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-29-57894c2077a7> in <module>
#       3 url = f'https://xn--80az8a.xn--d1aqf.xn--p1ai/%D1%81%D0%B5%D1%80%D0%B2%D0%B8%D1%81%D1%8B/api/kn/object?offset={offset_}&limit={limit_}&sortField=devId.devShortCleanNm&sortType=asc&objStatus=0'
#       4 res = requests.get(url)
# ----> 5 objects_data = res.json()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/models.py in json(self, **kwargs)
#     908                     # used.
#     909                     pass
# --> 910         return complexjson.loads(self.text, **kwargs)
#     911
#     912     @property
#
# ~/opt/anaconda3/lib/python3.8/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# ~/opt/anaconda3/lib/python3.8/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~/opt/anaconda3/lib/python3.8/json/decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
# res.json()

# %%
objects_data.keys()
# Out:
# dict_keys(['data', 'errcode'])

# %%
objects_data.get('data').keys()
# Out:
# dict_keys(['list', 'total'])

# %%
 objects_data.get('data').get('list')
# Out:
# [{'objId': 36774,
#   'developer': {'devId': 6926,
#    'shortName': 'ОКЕАН',
#    'fullName': 'ОКЕАН',
#    'groupName': 'Океан',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'companyGroup': 5767476001,
#    'devInn': '0277093608'},
#   'rpdRegionCd': 2,
#   'objAddr': 'г Уфа, ул Прибельская, д. 32, 32/1, 34',
#   'objFloorMin': 5,
#   'objFloorMax': 9,
#   'objElemLivingCnt': 0,
#   'objReady100PercDt': '2024-09-30',
#   'objSquareLiving': 0.0,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 54.6871,
#   'longitude': 55.9563,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 1,
#   'residentialBuildings': 0,
#   'rpdNum': '02-001200',
#   'pdId': 351714,
#   'buildType': 'Нежилое',
#   'objStatus': 0},
#  {'objId': 5208,
#   'developer': {'devId': 1228,
#    'shortName': 'ОЛИМП',
#    'fullName': 'ОЛИМП',
#    'groupName': 'Олимп',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'companyGroup': 6929203001,
#    'devInn': '2609800350'},
#   'rpdRegionCd': 26,
#   'objAddr': 'г Ессентуки, улица Пригородная, д. 14 этап строительства Поз.2',
#   'objCommercNm': 'Жилой Комплекс "Кленовая роща"',
#   'objFloorMin': 8,
#   'objFloorMax': 8,
#   'objElemLivingCnt': 63,
#   'objReady100PercDt': '2024-09-30',
#   'objSquareLiving': 2339.61,
#   'objCompensFundFlg': 1,
#   'objProblemFlg': 0,
#   'latitude': 44.0657,
#   'longitude': 42.8646,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 0,
#   'residentialBuildings': 1,
#   'rpdNum': '26-000047',
#   'pdId': 4534,
#   'buildType': 'Жилое',
#   'objStatus': 0},
#  {'objId': 5207,
#   'developer': {'devId': 1228,
#    'shortName': 'ОЛИМП',
#    'fullName': 'ОЛИМП',
#    'groupName': 'Олимп',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'companyGroup': 6929203001,
#    'devInn': '2609800350'},
#   'rpdRegionCd': 26,
#   'objAddr': 'г Ессентуки, улица Пригородная, д. 13 этап строительства Поз.4',
#   'objCommercNm': 'Жилой Комплекс "Кленовая роща"',
#   'objFloorMin': 8,
#   'objFloorMax': 8,
#   'objElemLivingCnt': 63,
#   'objReady100PercDt': '2023-09-30',
#   'objSquareLiving': 2339.61,
#   'objCompensFundFlg': 1,
#   'objProblemFlg': 0,
#   'latitude': 44.0629,
#   'longitude': 42.8632,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 0,
#   'residentialBuildings': 1,
#   'rpdNum': '26-000047',
#   'pdId': 4534,
#   'buildType': 'Жилое',
#   'objStatus': 0},
#  {'objId': 5206,
#   'developer': {'devId': 1228,
#    'shortName': 'ОЛИМП',
#    'fullName': 'ОЛИМП',
#    'groupName': 'Олимп',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'companyGroup': 6929203001,
#    'devInn': '2609800350'},
#   'rpdRegionCd': 26,
#   'objAddr': 'г Ессентуки, улица Пригородная, д. 12 этап строительства Поз.6',
#   'objCommercNm': 'Жилой Комплекс "Кленовая роща"',
#   'objFloorMin': 8,
#   'objFloorMax': 8,
#   'objElemLivingCnt': 63,
#   'objReady100PercDt': '2022-12-31',
#   'objSquareLiving': 2339.61,
#   'objCompensFundFlg': 1,
#   'objProblemFlg': 0,
#   'latitude': 44.0657,
#   'longitude': 42.8656,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 0,
#   'residentialBuildings': 1,
#   'rpdNum': '26-000047',
#   'pdId': 4534,
#   'buildType': 'Жилое',
#   'objStatus': 0},
#  {'objId': 28951,
#   'developer': {'devId': 7517,
#    'shortName': 'ОЛИМП-ИНВЕСТ',
#    'fullName': 'ОЛИМП-ИНВЕСТ',
#    'groupName': 'Росинмонолитстрой',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'companyGroup': 6077106001,
#    'devInn': '2703097744'},
#   'rpdRegionCd': 27,
#   'objAddr': 'город Комсомольск-на-Амуре, проспект Первостроителей, д. 0, литера 0, корпус 0, строение 0, вл. 0',
#   'objFloorMin': 17,
#   'objFloorMax': 17,
#   'objElemLivingCnt': 84,
#   'objReady100PercDt': '2022-09-30',
#   'objSquareLiving': 4894.96,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 50.5394,
#   'longitude': 137.0072,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 1,
#   'residentialBuildings': 1,
#   'rpdNum': '27-000221',
#   'pdId': 104953,
#   'buildType': 'Жилое',
#   'objStatus': 0},
#  {'objId': 16849,
#   'developer': {'devId': 4010,
#    'shortName': 'ОМЕГА',
#    'fullName': 'ОМЕГА',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'devInn': '5262285024'},
#   'rpdRegionCd': 52,
#   'objAddr': 'г Кстово, 6 микрорайон, 6 микрорайон, д. 6',
#   'objCommercNm': 'Жилой комплекс "Ватсон", ЖК "Ватсон"',
#   'objFloorMin': 5,
#   'objFloorMax': 5,
#   'objElemLivingCnt': 52,
#   'objReady100PercDt': '2023-06-30',
#   'objSquareLiving': 2199.76,
#   'objCompensFundFlg': 1,
#   'objProblemFlg': 0,
#   'latitude': 56.1641,
#   'longitude': 44.1901,
#   'complexShortName': 'Ватсон',
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 0,
#   'residentialBuildings': 1,
#   'rpdNum': '52-000182',
#   'pdId': 33847,
#   'buildType': 'Жилое',
#   'objStatus': 0},
#  {'objId': 16847,
#   'developer': {'devId': 4010,
#    'shortName': 'ОМЕГА',
#    'fullName': 'ОМЕГА',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'devInn': '5262285024'},
#   'rpdRegionCd': 52,
#   'objAddr': 'г Кстово, 6 микрорайон, 6 микрорайон, д. 5',
#   'objCommercNm': 'Жилой комплекс "Ватсон", ЖК "Ватсон"',
#   'objFloorMin': 5,
#   'objFloorMax': 5,
#   'objElemLivingCnt': 76,
#   'objReady100PercDt': '2022-06-30',
#   'objSquareLiving': 3322.16,
#   'objCompensFundFlg': 1,
#   'objProblemFlg': 0,
#   'latitude': 56.1638,
#   'longitude': 44.1909,
#   'complexShortName': 'Ватсон',
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 0,
#   'residentialBuildings': 1,
#   'rpdNum': '52-000182',
#   'pdId': 33847,
#   'buildType': 'Жилое',
#   'objStatus': 0},
#  {'objId': 16850,
#   'developer': {'devId': 4010,
#    'shortName': 'ОМЕГА',
#    'fullName': 'ОМЕГА',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'devInn': '5262285024'},
#   'rpdRegionCd': 52,
#   'objAddr': 'г Кстово, 6 микрорайон, 6 микрорайон, д. 7',
#   'objCommercNm': 'Жилой комплекс "Ватсон", ЖК "Ватсон"',
#   'objFloorMin': 5,
#   'objFloorMax': 5,
#   'objElemLivingCnt': 76,
#   'objReady100PercDt': '2025-03-31',
#   'objSquareLiving': 3322.16,
#   'objCompensFundFlg': 1,
#   'objProblemFlg': 0,
#   'latitude': 56.1638,
#   'longitude': 44.1894,
#   'complexShortName': 'Ватсон',
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 0,
#   'residentialBuildings': 1,
#   'rpdNum': '52-000182',
#   'pdId': 33847,
#   'buildType': 'Жилое',
#   'objStatus': 0},
#  {'objId': 16851,
#   'developer': {'devId': 4010,
#    'shortName': 'ОМЕГА',
#    'fullName': 'ОМЕГА',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'devInn': '5262285024'},
#   'rpdRegionCd': 52,
#   'objAddr': 'г Кстово, 6 микрорайон, 6 микрорайон, д. 8',
#   'objCommercNm': 'Жилой комплекс "Ватсон", ЖК "Ватсон"',
#   'objFloorMin': 5,
#   'objFloorMax': 5,
#   'objElemLivingCnt': 52,
#   'objReady100PercDt': '2025-03-31',
#   'objSquareLiving': 2199.76,
#   'objCompensFundFlg': 1,
#   'objProblemFlg': 0,
#   'latitude': 56.1643,
#   'longitude': 44.1888,
#   'complexShortName': 'Ватсон',
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 0,
#   'residentialBuildings': 1,
#   'rpdNum': '52-000182',
#   'pdId': 33847,
#   'buildType': 'Жилое',
#   'objStatus': 0},
#  {'objId': 13038,
#   'developer': {'devId': 3189,
#    'shortName': 'ОНЕГОСТРОЙСЕРВИС',
#    'fullName': 'ОНЕГОСТРОЙСЕРВИС',
#    'groupName': 'Баренц Групп',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'companyGroup': 410208001,
#    'devInn': '1001280955'},
#   'rpdRegionCd': 10,
#   'objAddr': 'г Петрозаводск',
#   'objCommercNm': 'Свиристель 19 дом',
#   'objFloorMin': 9,
#   'objFloorMax': 9,
#   'objElemLivingCnt': 72,
#   'objReady100PercDt': '2022-12-31',
#   'objSquareLiving': 3365.34,
#   'objCompensFundFlg': 1,
#   'objProblemFlg': 0,
#   'latitude': 61.7847,
#   'longitude': 34.3458,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 0,
#   'residentialBuildings': 1,
#   'rpdNum': '10-000046',
#   'pdId': 27227,
#   'buildType': 'Жилое',
#   'objStatus': 0},
#  {'objId': 13037,
#   'developer': {'devId': 3189,
#    'shortName': 'ОНЕГОСТРОЙСЕРВИС',
#    'fullName': 'ОНЕГОСТРОЙСЕРВИС',
#    'groupName': 'Баренц Групп',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'companyGroup': 410208001,
#    'devInn': '1001280955'},
#   'rpdRegionCd': 10,
#   'objAddr': 'г Петрозаводск',
#   'objCommercNm': 'Свиристель 18.3 дом',
#   'objFloorMin': 16,
#   'objFloorMax': 16,
#   'objElemLivingCnt': 139,
#   'objReady100PercDt': '2022-06-30',
#   'objSquareLiving': 6082.75,
#   'objCompensFundFlg': 1,
#   'objProblemFlg': 0,
#   'latitude': 61.7847,
#   'longitude': 34.3458,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 0,
#   'residentialBuildings': 1,
#   'rpdNum': '10-000046',
#   'pdId': 27227,
#   'buildType': 'Жилое',
#   'objStatus': 0},
#  {'objId': 13035,
#   'developer': {'devId': 3189,
#    'shortName': 'ОНЕГОСТРОЙСЕРВИС',
#    'fullName': 'ОНЕГОСТРОЙСЕРВИС',
#    'groupName': 'Баренц Групп',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'companyGroup': 410208001,
#    'devInn': '1001280955'},
#   'rpdRegionCd': 10,
#   'objAddr': 'г Петрозаводск',
#   'objCommercNm': 'Свиристель 17 дом',
#   'objFloorMin': 9,
#   'objFloorMax': 16,
#   'objElemLivingCnt': 278,
#   'objReady100PercDt': '2022-12-31',
#   'objSquareLiving': 11073.61,
#   'objCompensFundFlg': 1,
#   'objProblemFlg': 0,
#   'latitude': 61.7847,
#   'longitude': 34.3458,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 0,
#   'residentialBuildings': 1,
#   'rpdNum': '10-000046',
#   'pdId': 27227,
#   'buildType': 'Жилое',
#   'objStatus': 0},
#  {'objId': 20169,
#   'developer': {'devId': 3587,
#    'shortName': 'ОНИКС',
#    'fullName': 'ОНИКС',
#    'groupName': 'Запстрой',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'companyGroup': 2494053001,
#    'devInn': '4705045632'},
#   'rpdRegionCd': 47,
#   'objAddr': 'п Мурино, Проспект Ручьевский, корпус 2',
#   'objCommercNm': 'ЖК "Мурино Парк"',
#   'objFloorMin': 21,
#   'objFloorMax': 21,
#   'objElemLivingCnt': 216,
#   'objReady100PercDt': '2022-12-31',
#   'objSquareLiving': 7260.46,
#   'objCompensFundFlg': 1,
#   'objProblemFlg': 0,
#   'latitude': 60.0647,
#   'longitude': 30.4383,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 0,
#   'residentialBuildings': 1,
#   'rpdNum': '47-000277',
#   'pdId': 49112,
#   'buildType': 'Жилое',
#   'objStatus': 0},
#  {'objId': 20170,
#   'developer': {'devId': 3587,
#    'shortName': 'ОНИКС',
#    'fullName': 'ОНИКС',
#    'groupName': 'Запстрой',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'companyGroup': 2494053001,
#    'devInn': '4705045632'},
#   'rpdRegionCd': 47,
#   'objAddr': 'п Мурино, Проспект Ручьевский, д. Дошкольноеобщеобразовательноеучреждение',
#   'objCommercNm': 'ЖК "Мурино Парк"',
#   'objFloorMin': 2,
#   'objFloorMax': 2,
#   'objElemLivingCnt': 0,
#   'objReady100PercDt': '2022-12-31',
#   'objSquareLiving': 0.0,
#   'objCompensFundFlg': 1,
#   'objProblemFlg': 0,
#   'latitude': 60.065,
#   'longitude': 30.4385,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 0,
#   'residentialBuildings': 0,
#   'rpdNum': '47-000277',
#   'pdId': 49112,
#   'buildType': 'Нежилое',
#   'objStatus': 0},
#  {'objId': 20168,
#   'developer': {'devId': 3587,
#    'shortName': 'ОНИКС',
#    'fullName': 'ОНИКС',
#    'groupName': 'Запстрой',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'companyGroup': 2494053001,
#    'devInn': '4705045632'},
#   'rpdRegionCd': 47,
#   'objAddr': 'п Мурино, Проспект Ручьевский, д. Гараж',
#   'objCommercNm': 'ЖК "Мурино Парк"',
#   'objFloorMin': 1,
#   'objFloorMax': 1,
#   'objElemLivingCnt': 0,
#   'objReady100PercDt': '2021-12-31',
#   'objSquareLiving': 0.0,
#   'objCompensFundFlg': 1,
#   'objProblemFlg': 0,
#   'latitude': 60.0646,
#   'longitude': 30.4386,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 0,
#   'residentialBuildings': 0,
#   'rpdNum': '47-000277',
#   'pdId': 49112,
#   'buildType': 'Нежилое',
#   'objStatus': 0},
#  {'objId': 30257,
#   'developer': {'devId': 7828,
#    'shortName': 'ОНИКС',
#    'fullName': 'ОНИКС',
#    'groupName': 'СИБИРИЯ',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'companyGroup': 5047730001,
#    'devInn': '2225196300'},
#   'rpdRegionCd': 22,
#   'objAddr': 'город Барнаул, тракт Змеиногорский, д. 35а/2, блок-секция 1,2',
#   'objCommercNm': 'ЖК Барнаульский лес',
#   'objFloorMin': 10,
#   'objFloorMax': 10,
#   'objElemLivingCnt': 107,
#   'objReady100PercDt': '2022-06-30',
#   'objSquareLiving': 4725.34,
#   'objCompensFundFlg': 1,
#   'objProblemFlg': 0,
#   'latitude': 53.4372,
#   'longitude': 83.269,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 0,
#   'residentialBuildings': 1,
#   'rpdNum': '22-000279',
#   'pdId': 133244,
#   'buildType': 'Жилое',
#   'objStatus': 0},
#  {'objId': 20167,
#   'developer': {'devId': 3587,
#    'shortName': 'ОНИКС',
#    'fullName': 'ОНИКС',
#    'groupName': 'Запстрой',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'companyGroup': 2494053001,
#    'devInn': '4705045632'},
#   'rpdRegionCd': 47,
#   'objAddr': 'п Мурино',
#   'objCommercNm': 'ЖК "Мурино Парк"',
#   'objFloorMin': 21,
#   'objFloorMax': 21,
#   'objElemLivingCnt': 900,
#   'objReady100PercDt': '2021-12-31',
#   'objSquareLiving': 29143.82,
#   'objCompensFundFlg': 1,
#   'objProblemFlg': 0,
#   'latitude': 60.0648,
#   'longitude': 30.4375,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 0,
#   'residentialBuildings': 1,
#   'rpdNum': '47-000277',
#   'pdId': 49112,
#   'buildType': 'Жилое',
#   'objStatus': 0},
#  {'objId': 41973,
#   'developer': {'devId': 8971,
#    'shortName': 'ООО СЗ ВОЛГА ТЕЛЕКОМ-ИНВЕСТ',
#    'fullName': 'СПЕЦИАЛИЗИРОВАННЫЙ ЗАСТРОЙЩИК ВОЛГА ТЕЛЕКОМ-ИНВЕСТ',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'devInn': '3444112223'},
#   'rpdRegionCd': 34,
#   'objAddr': 'г Волгоград, район Дзержинский, ул им Полоненко, д. 4',
#   'objFloorMin': 21,
#   'objFloorMax': 21,
#   'objElemLivingCnt': 136,
#   'objReady100PercDt': '2022-12-31',
#   'objSquareLiving': 8357.01,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 48.7154,
#   'longitude': 44.4686,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 1,
#   'residentialBuildings': 1,
#   'rpdNum': '34-000588',
#   'pdId': 242508,
#   'buildType': 'Жилое',
#   'objStatus': 0},
#  {'objId': 38852,
#   'developer': {'devId': 1664,
#    'shortName': 'ООО СЗ РЕМСТРОЙ',
#    'fullName': 'СПЕЦИАЛИЗИРОВАННЫЙ ЗАСТРОЙЩИК РЕМСТРОЙ',
#    'groupName': 'Ремстрой',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'companyGroup': 3633020001,
#    'devInn': '5838042939'},
#   'rpdRegionCd': 58,
#   'objAddr': 'г Заречный, улица Ленина, д. 55А',
#   'objCommercNm': 'SKY PARK',
#   'objFloorMin': 11,
#   'objFloorMax': 11,
#   'objElemLivingCnt': 90,
#   'objReady100PercDt': '2022-06-30',
#   'objSquareLiving': 6280.26,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 53.2019,
#   'longitude': 45.1554,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 1,
#   'residentialBuildings': 1,
#   'rpdNum': '58-000301',
#   'pdId': 371244,
#   'buildType': 'Жилое',
#   'objStatus': 0},
#  {'objId': 31790,
#   'developer': {'devId': 6467,
#    'shortName': 'ОПАЛИХА-СИТИ',
#    'fullName': 'ОПАЛИХА-СИТИ',
#    'groupName': 'Новард',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'companyGroup': 1153755001,
#    'devInn': '5024147481'},
#   'rpdRegionCd': 50,
#   'objAddr': 'г Красногорск, микрорайон Опалиха, корпус 1',
#   'objCommercNm': 'Миниполис Серебрица',
#   'objFloorMin': 9,
#   'objFloorMax': 13,
#   'objElemLivingCnt': 561,
#   'objReady100PercDt': '2022-03-31',
#   'objSquareLiving': 28949.3,
#   'objCompensFundFlg': 1,
#   'objProblemFlg': 0,
#   'latitude': 55.8298,
#   'longitude': 37.2348,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 0,
#   'residentialBuildings': 1,
#   'rpdNum': '50-002443',
#   'pdId': 153622,
#   'buildType': 'Жилое',
#   'objStatus': 0},
#  {'objId': 43161,
#   'developer': {'devId': 6467,
#    'shortName': 'ОПАЛИХА-СИТИ',
#    'fullName': 'ОПАЛИХА-СИТИ',
#    'groupName': 'Новард',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'companyGroup': 1153755001,
#    'devInn': '5024147481'},
#   'rpdRegionCd': 50,
#   'objAddr': 'г Красногорск, район Мкр.Опалиха',
#   'objCommercNm': 'Миниполис Серебрица',
#   'objFloorMin': 8,
#   'objFloorMax': 8,
#   'objElemLivingCnt': 0,
#   'objReady100PercDt': '2024-06-30',
#   'objSquareLiving': 0.0,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 55.8285,
#   'longitude': 37.234,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 1,
#   'residentialBuildings': 0,
#   'rpdNum': '50-003262',
#   'pdId': 506194,
#   'buildType': 'Нежилое',
#   'objStatus': 0},
#  {'objId': 31791,
#   'developer': {'devId': 6467,
#    'shortName': 'ОПАЛИХА-СИТИ',
#    'fullName': 'ОПАЛИХА-СИТИ',
#    'groupName': 'Новард',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'companyGroup': 1153755001,
#    'devInn': '5024147481'},
#   'rpdRegionCd': 50,
#   'objAddr': 'г Красногорск, микрорайон Опалиха, корпус 5',
#   'objCommercNm': 'Миниполис Серебрица',
#   'objFloorMin': 9,
#   'objFloorMax': 13,
#   'objElemLivingCnt': 513,
#   'objReady100PercDt': '2022-03-31',
#   'objSquareLiving': 23480.0,
#   'objCompensFundFlg': 1,
#   'objProblemFlg': 0,
#   'latitude': 55.8306,
#   'longitude': 37.2348,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 0,
#   'residentialBuildings': 1,
#   'rpdNum': '50-002444',
#   'pdId': 154449,
#   'buildType': 'Жилое',
#   'objStatus': 0},
#  {'objId': 40293,
#   'developer': {'devId': 6130,
#    'shortName': 'ОПТИМА-СТРОЙ',
#    'fullName': 'ОПТИМА-СТРОЙ',
#    'groupName': 'Оптима-Строй',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'companyGroup': 6170906001,
#    'devInn': '1435138983'},
#   'rpdRegionCd': 14,
#   'objAddr': 'г Якутск, ул Свердлова, д. 0',
#   'objFloorMin': 16,
#   'objFloorMax': 16,
#   'objElemLivingCnt': 143,
#   'objReady100PercDt': '2023-12-31',
#   'objSquareLiving': 5609.24,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 62.0451,
#   'longitude': 129.7322,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 1,
#   'residentialBuildings': 1,
#   'rpdNum': '14-000259',
#   'pdId': 434205,
#   'buildType': 'Жилое',
#   'objStatus': 0},
#  {'objId': 44223,
#   'developer': {'devId': 6130,
#    'shortName': 'ОПТИМА-СТРОЙ',
#    'fullName': 'ОПТИМА-СТРОЙ',
#    'groupName': 'Оптима-Строй',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'companyGroup': 6170906001,
#    'devInn': '1435138983'},
#   'rpdRegionCd': 14,
#   'objAddr': 'г Якутск, ул Кузьмина, литера 0',
#   'objFloorMin': 9,
#   'objFloorMax': 9,
#   'objElemLivingCnt': 149,
#   'objReady100PercDt': '2023-12-31',
#   'objSquareLiving': 5545.35,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 62.083,
#   'longitude': 129.7334,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 1,
#   'residentialBuildings': 1,
#   'rpdNum': '14-000274',
#   'pdId': 535485,
#   'buildType': 'Жилое',
#   'objStatus': 0},
#  {'objId': 40292,
#   'developer': {'devId': 6130,
#    'shortName': 'ОПТИМА-СТРОЙ',
#    'fullName': 'ОПТИМА-СТРОЙ',
#    'groupName': 'Оптима-Строй',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'companyGroup': 6170906001,
#    'devInn': '1435138983'},
#   'rpdRegionCd': 14,
#   'objAddr': 'г Якутск, ул Свердлова, д. 0',
#   'objFloorMin': 16,
#   'objFloorMax': 16,
#   'objElemLivingCnt': 143,
#   'objReady100PercDt': '2022-12-31',
#   'objSquareLiving': 5609.24,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 62.0452,
#   'longitude': 129.7325,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 1,
#   'residentialBuildings': 1,
#   'rpdNum': '14-000259',
#   'pdId': 434205,
#   'buildType': 'Жилое',
#   'objStatus': 0},
#  {'objId': 42142,
#   'developer': {'devId': 11925,
#    'shortName': 'ОПТТОРГ',
#    'fullName': 'ОПТТОРГ',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'devInn': '2465170633'},
#   'rpdRegionCd': 24,
#   'objAddr': 'г Дивногорск',
#   'objFloorMin': 6,
#   'objFloorMax': 6,
#   'objElemLivingCnt': 56,
#   'objReady100PercDt': '2022-06-30',
#   'objSquareLiving': 3152.36,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 55.9558,
#   'longitude': 92.3789,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 1,
#   'residentialBuildings': 1,
#   'rpdNum': '24-001009',
#   'pdId': 487995,
#   'buildType': 'Жилое',
#   'objStatus': 0},
#  {'objId': 11510,
#   'developer': {'devId': 3298,
#    'shortName': 'ОРДЖОНИКИДЗЕ 44',
#    'fullName': 'ОРДЖОНИКИДЗЕ 44',
#    'groupName': 'Becar Asset Management Group',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'companyGroup': 7920430001,
#    'devInn': '7825665048'},
#   'rpdRegionCd': 78,
#   'objAddr': 'г Санкт-Петербург, район Московский, улица Орджоникидзе, д. 44а, литера А',
#   'objCommercNm': 'Гостиничный комплекс на Орджоникидзе',
#   'objFloorMin': 26,
#   'objFloorMax': 27,
#   'objElemLivingCnt': 0,
#   'objReady100PercDt': '2025-09-30',
#   'objSquareLiving': 0.0,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 59.8444,
#   'longitude': 30.3427,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 1,
#   'residentialBuildings': 0,
#   'rpdNum': '78-000209',
#   'pdId': 24126,
#   'buildType': 'Нежилое',
#   'objStatus': 0},
#  {'objId': 11511,
#   'developer': {'devId': 3298,
#    'shortName': 'ОРДЖОНИКИДЗЕ 44',
#    'fullName': 'ОРДЖОНИКИДЗЕ 44',
#    'groupName': 'Becar Asset Management Group',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'companyGroup': 7920430001,
#    'devInn': '7825665048'},
#   'rpdRegionCd': 78,
#   'objAddr': 'г Санкт-Петербург, район Московский, улица Орджоникидзе, д. 44а, литера А',
#   'objCommercNm': 'Гостиничный комплекс на Орджоникидзе',
#   'objFloorMin': 26,
#   'objFloorMax': 27,
#   'objElemLivingCnt': 0,
#   'objReady100PercDt': '2025-09-30',
#   'objSquareLiving': 0.0,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 59.8444,
#   'longitude': 30.3427,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 1,
#   'residentialBuildings': 0,
#   'rpdNum': '78-000209',
#   'pdId': 24126,
#   'buildType': 'Нежилое',
#   'objStatus': 0},
#  {'objId': 11513,
#   'developer': {'devId': 3298,
#    'shortName': 'ОРДЖОНИКИДЗЕ 44',
#    'fullName': 'ОРДЖОНИКИДЗЕ 44',
#    'groupName': 'Becar Asset Management Group',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'companyGroup': 7920430001,
#    'devInn': '7825665048'},
#   'rpdRegionCd': 78,
#   'objAddr': 'г Санкт-Петербург, район Московский, улица Орджоникидзе, д. 44а, литера А',
#   'objCommercNm': 'Гостиничный комплекс на Орджоникидзе',
#   'objFloorMin': 27,
#   'objFloorMax': 27,
#   'objElemLivingCnt': 0,
#   'objReady100PercDt': '2025-09-30',
#   'objSquareLiving': 0.0,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 59.8444,
#   'longitude': 30.3426,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 1,
#   'residentialBuildings': 0,
#   'rpdNum': '78-000209',
#   'pdId': 24126,
#   'buildType': 'Нежилое',
#   'objStatus': 0},
#  {'objId': 11514,
#   'developer': {'devId': 3298,
#    'shortName': 'ОРДЖОНИКИДЗЕ 44',
#    'fullName': 'ОРДЖОНИКИДЗЕ 44',
#    'groupName': 'Becar Asset Management Group',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'companyGroup': 7920430001,
#    'devInn': '7825665048'},
#   'rpdRegionCd': 78,
#   'objAddr': 'г Санкт-Петербург, район Московский, улица Орджоникидзе, д. 44а, литера А',
#   'objCommercNm': 'Гостиничный комплекс на Орджоникидзе',
#   'objFloorMin': 27,
#   'objFloorMax': 27,
#   'objElemLivingCnt': 0,
#   'objReady100PercDt': '2025-09-30',
#   'objSquareLiving': 0.0,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 59.8444,
#   'longitude': 30.3427,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 1,
#   'residentialBuildings': 0,
#   'rpdNum': '78-000209',
#   'pdId': 24126,
#   'buildType': 'Нежилое',
#   'objStatus': 0},
#  {'objId': 11512,
#   'developer': {'devId': 3298,
#    'shortName': 'ОРДЖОНИКИДЗЕ 44',
#    'fullName': 'ОРДЖОНИКИДЗЕ 44',
#    'groupName': 'Becar Asset Management Group',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'companyGroup': 7920430001,
#    'devInn': '7825665048'},
#   'rpdRegionCd': 78,
#   'objAddr': 'г Санкт-Петербург, район Московский, улица Орджоникидзе, д. 44а, литера А',
#   'objCommercNm': 'Гостиничный комплекс на Орджоникидзе',
#   'objFloorMin': 27,
#   'objFloorMax': 27,
#   'objElemLivingCnt': 0,
#   'objReady100PercDt': '2025-09-30',
#   'objSquareLiving': 0.0,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 59.8445,
#   'longitude': 30.3427,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 1,
#   'residentialBuildings': 0,
#   'rpdNum': '78-000209',
#   'pdId': 24126,
#   'buildType': 'Нежилое',
#   'objStatus': 0},
#  {'objId': 42459,
#   'developer': {'devId': 86,
#    'shortName': 'ОРЕЛСТРОЙ',
#    'fullName': 'ОРЕЛСТРОЙ',
#    'groupName': 'ОДСК',
#    'orgForm': {'id': 2,
#     'fullForm': 'Публичное акционерное общество',
#     'shortForm': 'ПАО'},
#    'companyGroup': 1460205001,
#    'devInn': '5751005940'},
#   'rpdRegionCd': 57,
#   'objAddr': 'г Орёл, улица Зареченская, д. 6, корпус 3',
#   'objCommercNm': 'Жилищный Комплекс Аквамарин ЖК Аквамарин Жилой Квартал Аквамарин Жилой комплекс Аквамарин микрорайон Аквамарин мкрн Аквамарин Жилой квартал Аквамарин АКВАМАРИН ЖК АКВАМАРИН МКРН АКВАМАРИН ЖИЛОЙ КОМПЛЕКС АКВАМАРИН МИКРОРАЙОН АКВАМАРИН',
#   'objFloorMin': 18,
#   'objFloorMax': 18,
#   'objElemLivingCnt': 317,
#   'objReady100PercDt': '2022-12-31',
#   'objSquareLiving': 12693.6,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 52.9578,
#   'longitude': 36.0152,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 1,
#   'residentialBuildings': 1,
#   'rpdNum': '57-000162',
#   'pdId': 496096,
#   'buildType': 'Жилое',
#   'objStatus': 0},
#  {'objId': 38337,
#   'developer': {'devId': 86,
#    'shortName': 'ОРЕЛСТРОЙ',
#    'fullName': 'ОРЕЛСТРОЙ',
#    'groupName': 'ОДСК',
#    'orgForm': {'id': 2,
#     'fullForm': 'Публичное акционерное общество',
#     'shortForm': 'ПАО'},
#    'companyGroup': 1460205001,
#    'devInn': '5751005940'},
#   'rpdRegionCd': 57,
#   'objAddr': 'д Жилина, улица Генерала Лаврова, д. 1, корпус 3',
#   'objCommercNm': 'Микрорайон «Болховский», Микрорайон Болховский, Мкрн «Болховский», Мкрн Болховский, Болховский',
#   'objFloorMin': 18,
#   'objFloorMax': 18,
#   'objElemLivingCnt': 160,
#   'objReady100PercDt': '2022-06-30',
#   'objSquareLiving': 8785.0,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 52.9957,
#   'longitude': 36.066,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 1,
#   'residentialBuildings': 1,
#   'rpdNum': '57-000142',
#   'pdId': 407957,
#   'buildType': 'Жилое',
#   'objStatus': 0},
#  {'objId': 39532,
#   'developer': {'devId': 86,
#    'shortName': 'ОРЕЛСТРОЙ',
#    'fullName': 'ОРЕЛСТРОЙ',
#    'groupName': 'ОДСК',
#    'orgForm': {'id': 2,
#     'fullForm': 'Публичное акционерное общество',
#     'shortForm': 'ПАО'},
#    'companyGroup': 1460205001,
#    'devInn': '5751005940'},
#   'rpdRegionCd': 57,
#   'objAddr': 'д Жилина, улица Генерала Лаврова, д. 1, корпус 4',
#   'objCommercNm': 'Микрорайон"Болховский"Микрорайон Болховский Мкрн"Болховский"Мкрн Болховский Болховский',
#   'objFloorMin': 18,
#   'objFloorMax': 18,
#   'objElemLivingCnt': 301,
#   'objReady100PercDt': '2022-12-31',
#   'objSquareLiving': 12858.2,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 52.9959,
#   'longitude': 36.0654,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 1,
#   'residentialBuildings': 1,
#   'rpdNum': '57-000155',
#   'pdId': 435637,
#   'buildType': 'Жилое',
#   'objStatus': 0},
#  {'objId': 37551,
#   'developer': {'devId': 86,
#    'shortName': 'ОРЕЛСТРОЙ',
#    'fullName': 'ОРЕЛСТРОЙ',
#    'groupName': 'ОДСК',
#    'orgForm': {'id': 2,
#     'fullForm': 'Публичное акционерное общество',
#     'shortForm': 'ПАО'},
#    'companyGroup': 1460205001,
#    'devInn': '5751005940'},
#   'rpdRegionCd': 57,
#   'objAddr': 'г Орёл, улица Космонавтов, д. 48, корпус 2',
#   'objCommercNm': 'Микрорайон «Московский парк», Микрорайон Московский парк, Мкрн «Московский парк», Мкрн Московский парк, Московский парк, ЖК «Московский парк», Жилищный Комплекс «Московский парк», Жилой Квартал «Московский парк», МР «Московский парк»',
#   'objFloorMin': 3,
#   'objFloorMax': 18,
#   'objElemLivingCnt': 239,
#   'objReady100PercDt': '2022-09-30',
#   'objSquareLiving': 12807.2,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 52.9964,
#   'longitude': 36.1219,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 1,
#   'residentialBuildings': 1,
#   'rpdNum': '57-000130',
#   'pdId': 340386,
#   'buildType': 'Жилое',
#   'objStatus': 0},
#  {'objId': 38972,
#   'developer': {'devId': 86,
#    'shortName': 'ОРЕЛСТРОЙ',
#    'fullName': 'ОРЕЛСТРОЙ',
#    'groupName': 'ОДСК',
#    'orgForm': {'id': 2,
#     'fullForm': 'Публичное акционерное общество',
#     'shortForm': 'ПАО'},
#    'companyGroup': 1460205001,
#    'devInn': '5751005940'},
#   'rpdRegionCd': 57,
#   'objAddr': 'г Орёл, улица Космонавтов, д. 48, корпус 3',
#   'objCommercNm': 'Микрорайон Московский парк Микрорайон Московский парк Мкрн Московский парк Мкрн Московский парк Московский парк Ж К Московский парк Жилищный Комплекс Московский парк Жилой Квартал Московский парк МР Московский парк',
#   'objFloorMin': 18,
#   'objFloorMax': 18,
#   'objElemLivingCnt': 175,
#   'objReady100PercDt': '2022-09-30',
#   'objSquareLiving': 8560.2,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 52.9943,
#   'longitude': 36.1267,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 1,
#   'residentialBuildings': 1,
#   'rpdNum': '57-000147',
#   'pdId': 418069,
#   'buildType': 'Жилое',
#   'objStatus': 0},
#  {'objId': 38338,
#   'developer': {'devId': 86,
#    'shortName': 'ОРЕЛСТРОЙ',
#    'fullName': 'ОРЕЛСТРОЙ',
#    'groupName': 'ОДСК',
#    'orgForm': {'id': 2,
#     'fullForm': 'Публичное акционерное общество',
#     'shortForm': 'ПАО'},
#    'companyGroup': 1460205001,
#    'devInn': '5751005940'},
#   'rpdRegionCd': 57,
#   'objAddr': 'г Орёл, улица Зареченская, д. 4, корпус 3',
#   'objCommercNm': 'Жилищный Комплекс Маяк ЖК Маяк Жилой дом Маяк Жилой комплекс Маяк МАЯК ЖК МАЯК ЖИЛОЙ КОМПЛЕКС МАЯК',
#   'objFloorMin': 22,
#   'objFloorMax': 22,
#   'objElemLivingCnt': 140,
#   'objReady100PercDt': '2022-12-31',
#   'objSquareLiving': 8285.0,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 52.9576,
#   'longitude': 36.0184,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 1,
#   'residentialBuildings': 1,
#   'rpdNum': '57-000143',
#   'pdId': 407976,
#   'buildType': 'Жилое',
#   'objStatus': 0},
#  {'objId': 40195,
#   'developer': {'devId': 86,
#    'shortName': 'ОРЕЛСТРОЙ',
#    'fullName': 'ОРЕЛСТРОЙ',
#    'groupName': 'ОДСК',
#    'orgForm': {'id': 2,
#     'fullForm': 'Публичное акционерное общество',
#     'shortForm': 'ПАО'},
#    'companyGroup': 1460205001,
#    'devInn': '5751005940'},
#   'rpdRegionCd': 57,
#   'objAddr': 'г Орёл, улица Зареченская, д. 6, корпус 4',
#   'objCommercNm': 'Жилищный Комплекс Аквамарин ЖК Аквамарин Жилой Квартал Аквамарин Жилой комплекс Аквамарин микрорайон Аквамарин мкрн Аквамарин Жилой квартал Аквамарин АКВАМАРИН ЖК АКВАМАРИН МКРН АКВАМАРИН ЖИЛОЙ КОМПЛЕКС АКВАМАРИН МИКРОРАЙОН АКВАМАРИН',
#   'objFloorMin': 18,
#   'objFloorMax': 18,
#   'objElemLivingCnt': 223,
#   'objReady100PercDt': '2022-09-30',
#   'objSquareLiving': 8408.2,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 52.9576,
#   'longitude': 36.0162,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 1,
#   'residentialBuildings': 1,
#   'rpdNum': '57-000159',
#   'pdId': 448250,
#   'buildType': 'Жилое',
#   'objStatus': 0},
#  {'objId': 39533,
#   'developer': {'devId': 86,
#    'shortName': 'ОРЕЛСТРОЙ',
#    'fullName': 'ОРЕЛСТРОЙ',
#    'groupName': 'ОДСК',
#    'orgForm': {'id': 2,
#     'fullForm': 'Публичное акционерное общество',
#     'shortForm': 'ПАО'},
#    'companyGroup': 1460205001,
#    'devInn': '5751005940'},
#   'rpdRegionCd': 57,
#   'objAddr': 'г Орёл, улица Зареченская, д. 6, корпус 2',
#   'objCommercNm': 'Жилищный Комплекс Аквамарин ЖК Аквамарин Жилой Квартал Аквамарин Жилой комплекс Аквамарин микрорайон Аквамарин мкрн Аквамарин Жилой квартал Аквамарин АКВАМАРИН ЖК АКВАМАРИН МКРН АКВАМАРИН ЖИЛОЙ КОМПЛЕКС АКВАМАРИН МИКРОРАЙОН АКВАМАРИН',
#   'objFloorMin': 18,
#   'objFloorMax': 18,
#   'objElemLivingCnt': 240,
#   'objReady100PercDt': '2022-12-31',
#   'objSquareLiving': 12730.8,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 52.9582,
#   'longitude': 36.0168,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 1,
#   'residentialBuildings': 1,
#   'rpdNum': '57-000156',
#   'pdId': 438049,
#   'buildType': 'Жилое',
#   'objStatus': 0},
#  {'objId': 26250,
#   'developer': {'devId': 6287,
#    'shortName': 'ОРИОН',
#    'fullName': 'ОРИОН',
#    'groupName': 'ОРИОН',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'companyGroup': 156056864,
#    'devInn': '7838437680'},
#   'rpdRegionCd': 78,
#   'objAddr': 'г Санкт-Петербург, ул Большая Разночинная, д. 19а, литера А',
#   'objCommercNm': 'Family Loft',
#   'objFloorMin': 1,
#   'objFloorMax': 10,
#   'objElemLivingCnt': 57,
#   'objReady100PercDt': '2023-12-31',
#   'objSquareLiving': 5358.57,
#   'objCompensFundFlg': 1,
#   'objProblemFlg': 0,
#   'latitude': 59.9608,
#   'longitude': 30.288,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 0,
#   'residentialBuildings': 1,
#   'rpdNum': '78-000550',
#   'pdId': 42319,
#   'buildType': 'Жилое',
#   'objStatus': 0},
#  {'objId': 28392,
#   'developer': {'devId': 1750,
#    'shortName': 'ОСК',
#    'fullName': 'ОБЪЕДИНЕННАЯ СТРОИТЕЛЬНАЯ КОРПОРАЦИЯ',
#    'groupName': 'Объединенная строительная корпорация',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'companyGroup': 5903188001,
#    'devInn': '3444197890'},
#   'rpdRegionCd': 34,
#   'objAddr': 'г Волгоград, б-р 30-летия Победы, д. 19, корпус Б, блок-секция 2',
#   'objCommercNm': 'Жилой комплекс «Дом на Бульваре»',
#   'objFloorMin': 20,
#   'objFloorMax': 20,
#   'objElemLivingCnt': 172,
#   'objReady100PercDt': '2022-12-31',
#   'objSquareLiving': 8157.11,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 48.7469,
#   'longitude': 44.4958,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 0,
#   'residentialBuildings': 1,
#   'rpdNum': '34-000315',
#   'pdId': 101730,
#   'buildType': 'Жилое',
#   'objStatus': 0},
#  {'objId': 19990,
#   'developer': {'devId': 2618,
#    'shortName': 'ОСНОВА',
#    'fullName': 'ОСНОВА',
#    'groupName': 'Основа',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'companyGroup': 7596062001,
#    'devInn': '7456009066'},
#   'rpdRegionCd': 2,
#   'objAddr': 'г Белорецк, ул. Твердышева, д. 40',
#   'objCommercNm': 'Твердышева 40, дом №1',
#   'objFloorMin': 3,
#   'objFloorMax': 3,
#   'objElemLivingCnt': 51,
#   'objReady100PercDt': '2022-06-30',
#   'objSquareLiving': 2095.2,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 53.9702,
#   'longitude': 58.4437,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 0,
#   'residentialBuildings': 1,
#   'rpdNum': '02-000414',
#   'pdId': 48999,
#   'buildType': 'Жилое',
#   'objStatus': 0},
#  {'objId': 6031,
#   'developer': {'devId': 1008,
#    'shortName': 'ОСНОВА',
#    'fullName': 'ОСНОВА',
#    'groupName': 'Основа',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'companyGroup': 5061195001,
#    'devInn': '7411075301'},
#   'rpdRegionCd': 74,
#   'objAddr': 'г Копейск, улица Жданова, д. 29-В',
#   'objFloorMin': 16,
#   'objFloorMax': 16,
#   'objElemLivingCnt': 84,
#   'objReady100PercDt': '2022-12-31',
#   'objSquareLiving': 5841.1,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 55.113,
#   'longitude': 61.6081,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 1,
#   'residentialBuildings': 1,
#   'rpdNum': '74-000521',
#   'pdId': 13004,
#   'buildType': 'Жилое',
#   'objStatus': 0},
#  {'objId': 36262,
#   'developer': {'devId': 10306,
#    'shortName': 'ОСНОВА',
#    'fullName': 'ОСНОВА - CПЕЦИАЛИЗИРОВАННЫЙ ЗАСТРОЙЩИК',
#    'groupName': 'Острова',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'companyGroup': 827094001,
#    'devInn': '1831198344'},
#   'rpdRegionCd': 18,
#   'objAddr': 'г Ижевск, район Первомайский, блок-секция 1-3',
#   'objCommercNm': 'Коммерческое обозначение объекта: «Жилой комплекс Новый Карлутский»; «Жилой дом Новый Карлутский»; «Новый Карлутский - дом в сердце района»; «Новый Карлутский - дом который меняет Соцгород к лучшему»; «Жилой квартал Новый Карлутский». Коммерческое название строящегося здания: «Жилой комплекс Новый Карлутский»',
#   'objFloorMin': 17,
#   'objFloorMax': 17,
#   'objElemLivingCnt': 270,
#   'objReady100PercDt': '2022-12-31',
#   'objSquareLiving': 14146.4,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 56.8403,
#   'longitude': 53.2403,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 1,
#   'residentialBuildings': 1,
#   'rpdNum': '18-000409',
#   'pdId': 332888,
#   'buildType': 'Жилое',
#   'objStatus': 0},
#  {'objId': 37597,
#   'developer': {'devId': 792,
#    'shortName': 'ОСНОВАНИЕ',
#    'fullName': 'ОСНОВАНИЕ',
#    'groupName': 'Основание',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'companyGroup': 5954671001,
#    'devInn': '6950134821'},
#   'rpdRegionCd': 69,
#   'objAddr': 'г Тверь, улица Скворцова-Степанова, д. 15',
#   'objCommercNm': 'Жилой комплекс «Победа»',
#   'objFloorMin': 15,
#   'objFloorMax': 17,
#   'objElemLivingCnt': 162,
#   'objReady100PercDt': '2024-03-31',
#   'objSquareLiving': 14271.68,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 56.8736,
#   'longitude': 35.8891,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 1,
#   'residentialBuildings': 1,
#   'rpdNum': '69-000603',
#   'pdId': 348656,
#   'buildType': 'Жилое',
#   'objStatus': 0},
#  {'objId': 41117,
#   'developer': {'devId': 8466,
#    'shortName': 'ПАКС',
#    'fullName': 'ПЯТИГОРСКАВТОКОМСЕРВИС',
#    'orgForm': {'id': 1, 'fullForm': 'Акционерное общество', 'shortForm': 'АО'},
#    'devInn': '2632024289'},
#   'rpdRegionCd': 26,
#   'objAddr': 'г Пятигорск, улица Нежнова, д. 19',
#   'objFloorMin': 10,
#   'objFloorMax': 10,
#   'objElemLivingCnt': 62,
#   'objReady100PercDt': '2022-06-30',
#   'objSquareLiving': 4163.3,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 44.0352,
#   'longitude': 43.0494,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 1,
#   'residentialBuildings': 1,
#   'rpdNum': '26-000664',
#   'pdId': 186373,
#   'buildType': 'Жилое',
#   'objStatus': 0},
#  {'objId': 43963,
#   'developer': {'devId': 13426,
#    'shortName': 'ПАЛЬМИРА',
#    'fullName': 'ПАЛЬМИРА',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'devInn': '7842516046'},
#   'rpdRegionCd': 47,
#   'objAddr': 'гп Рощино, пер Садовый, д. 2, корпус 1',
#   'objFloorMin': 6,
#   'objFloorMax': 6,
#   'objElemLivingCnt': 58,
#   'objReady100PercDt': '2022-09-30',
#   'objSquareLiving': 1932.43,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 60.2545,
#   'longitude': 29.5967,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 1,
#   'residentialBuildings': 1,
#   'rpdNum': '47-000930',
#   'pdId': 535609,
#   'buildType': 'Жилое',
#   'objStatus': 0},
#  {'objId': 30089,
#   'developer': {'devId': 4712,
#    'shortName': 'ПАНОРАМА',
#    'fullName': 'ПАНОРАМА',
#    'groupName': 'Панорама',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'companyGroup': 6021905001,
#    'devInn': '6163000128'},
#   'rpdRegionCd': 61,
#   'objAddr': 'г Ростов-на-Дону, район Кировский, ул Береговая, д. 55а',
#   'objFloorMin': 22,
#   'objFloorMax': 22,
#   'objElemLivingCnt': 65,
#   'objReady100PercDt': '2023-09-30',
#   'objSquareLiving': 8370.72,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 47.2184,
#   'longitude': 39.7312,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 1,
#   'residentialBuildings': 1,
#   'rpdNum': '61-000829',
#   'pdId': 134349,
#   'buildType': 'Жилое',
#   'objStatus': 0},
#  {'objId': 31752,
#   'developer': {'devId': 8136,
#    'shortName': 'ПАНОРАМАИНВЕСТ',
#    'fullName': 'ПАНОРАМАИНВЕСТ',
#    'groupName': 'ЭкоСити',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'companyGroup': 5504490001,
#    'devInn': '7460044666'},
#   'rpdRegionCd': 74,
#   'objAddr': 'поселок Западный, д. 142, литера Челябинская область, Сосновский район, примерно в 3070 м. по направлению на юго- вост ок от ориентира д.Малиновка',
#   'objFloorMin': 3,
#   'objFloorMax': 3,
#   'objElemLivingCnt': 78,
#   'objReady100PercDt': '2023-06-30',
#   'objSquareLiving': 2020.65,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 55.0817,
#   'longitude': 61.2304,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 1,
#   'residentialBuildings': 1,
#   'rpdNum': '74-000864',
#   'pdId': 161364,
#   'buildType': 'Жилое',
#   'objStatus': 0},
#  {'objId': 31751,
#   'developer': {'devId': 8136,
#    'shortName': 'ПАНОРАМАИНВЕСТ',
#    'fullName': 'ПАНОРАМАИНВЕСТ',
#    'groupName': 'ЭкоСити',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'companyGroup': 5504490001,
#    'devInn': '7460044666'},
#   'rpdRegionCd': 74,
#   'objAddr': 'поселок Западный, д. 144',
#   'objFloorMin': 3,
#   'objFloorMax': 3,
#   'objElemLivingCnt': 78,
#   'objReady100PercDt': '2023-06-30',
#   'objSquareLiving': 2020.65,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 55.0804,
#   'longitude': 61.2302,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 1,
#   'residentialBuildings': 1,
#   'rpdNum': '74-000863',
#   'pdId': 161365,
#   'buildType': 'Жилое',
#   'objStatus': 0},
#  {'objId': 31753,
#   'developer': {'devId': 8136,
#    'shortName': 'ПАНОРАМАИНВЕСТ',
#    'fullName': 'ПАНОРАМАИНВЕСТ',
#    'groupName': 'ЭкоСити',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'companyGroup': 5504490001,
#    'devInn': '7460044666'},
#   'rpdRegionCd': 74,
#   'objAddr': 'поселок Западный, д. 141',
#   'objFloorMin': 3,
#   'objFloorMax': 3,
#   'objElemLivingCnt': 78,
#   'objReady100PercDt': '2023-06-30',
#   'objSquareLiving': 2020.65,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 55.0813,
#   'longitude': 61.2286,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 1,
#   'residentialBuildings': 1,
#   'rpdNum': '74-000865',
#   'pdId': 161219,
#   'buildType': 'Жилое',
#   'objStatus': 0},
#  {'objId': 23169,
#   'developer': {'devId': 3978,
#    'shortName': 'ПАРК',
#    'fullName': 'ПАРК',
#    'groupName': 'Парк',
#    'orgForm': {'id': 20,
#     'fullForm': 'Жилищный или жилищно-строительный кооператив',
#     'shortForm': 'ЖСК'},
#    'companyGroup': 6073158001,
#    'devInn': '6454140218'},
#   'rpdRegionCd': 64,
#   'objAddr': 'Саратов, улица Новоузенская, д. 219',
#   'objFloorMin': 2,
#   'objFloorMax': 2,
#   'objElemLivingCnt': 6,
#   'objReady100PercDt': '2021-12-31',
#   'objSquareLiving': 1620.0,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 51.539,
#   'longitude': 45.9677,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 1,
#   'residentialBuildings': 1,
#   'rpdNum': '64-000069',
#   'pdId': 33368,
#   'buildType': 'Жилое',
#   'objStatus': 0},
#  {'objId': 42427,
#   'developer': {'devId': 3978,
#    'shortName': 'ПАРК',
#    'fullName': 'ПАРК',
#    'groupName': 'Парк',
#    'orgForm': {'id': 20,
#     'fullForm': 'Жилищный или жилищно-строительный кооператив',
#     'shortForm': 'ЖСК'},
#    'companyGroup': 6073158001,
#    'devInn': '6454140218'},
#   'rpdRegionCd': 64,
#   'objAddr': 'г Саратов, ул Новоузенская, д. 219',
#   'objFloorMin': 3,
#   'objFloorMax': 3,
#   'objElemLivingCnt': 10,
#   'objReady100PercDt': '2022-09-30',
#   'objSquareLiving': 2264.7,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 51.5389,
#   'longitude': 45.9684,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 1,
#   'residentialBuildings': 1,
#   'rpdNum': '64-000394',
#   'pdId': 497384,
#   'buildType': 'Жилое',
#   'objStatus': 0},
#  {'objId': 43825,
#   'developer': {'devId': 2995,
#    'shortName': 'ПАРКОВЫЙ',
#    'fullName': 'ПАРКОВЫЙ',
#    'groupName': 'ПАРКОВЫЙ',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'companyGroup': 156056290,
#    'devInn': '3257056071'},
#   'rpdRegionCd': 40,
#   'objAddr': 'г Обнинск',
#   'objCommercNm': 'ЖК Парковый центр',
#   'objFloorMin': 7,
#   'objFloorMax': 12,
#   'objElemLivingCnt': 150,
#   'objReady100PercDt': '2023-12-31',
#   'objSquareLiving': 7769.2,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 55.1148,
#   'longitude': 36.5898,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 1,
#   'residentialBuildings': 1,
#   'rpdNum': '40-000340',
#   'pdId': 529167,
#   'buildType': 'Жилое',
#   'objStatus': 0},
#  {'objId': 33991,
#   'developer': {'devId': 721,
#    'shortName': 'ПАРТНЕР',
#    'fullName': 'ПАРТНЕР',
#    'groupName': 'Воронежская Девелоперская Компания',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'companyGroup': 561202001,
#    'devInn': '3666163420'},
#   'rpdRegionCd': 36,
#   'objAddr': 'г Воронеж, улица Загоровского, д. 1/1, 1/2, 1/3, 1/4, 1/5',
#   'objCommercNm': 'ЖК "Россия. Пять столиц"',
#   'objFloorMin': 1,
#   'objFloorMax': 1,
#   'objElemLivingCnt': 0,
#   'objReady100PercDt': '2022-12-31',
#   'objSquareLiving': 0.0,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 51.7147,
#   'longitude': 39.1906,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 1,
#   'residentialBuildings': 0,
#   'rpdNum': '36-000447',
#   'pdId': 192656,
#   'buildType': 'Нежилое',
#   'objStatus': 0},
#  {'objId': 4009,
#   'developer': {'devId': 721,
#    'shortName': 'ПАРТНЕР',
#    'fullName': 'ПАРТНЕР',
#    'groupName': 'Воронежская Девелоперская Компания',
# ...
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 1,
#   'residentialBuildings': 1,
#   'rpdNum': '39-001174',
#   'pdId': 481712,
#   'buildType': 'Жилое',
#   'objStatus': 0},
#  {'objId': 41680,
#   'developer': {'devId': 12408,
#    'shortName': 'СЗ БОЕР КОНСТРАКШН',
#    'fullName': 'СПЕЦИАЛИЗИРОВАНЫЙ ЗАСТРОЙЩИК БОЕР КОНСТРАКШН',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'devInn': '4826144596'},
#   'rpdRegionCd': 48,
#   'objAddr': 'г Липецк, микрорайон Елецкий, д. II-12',
#   'objCommercNm': 'Жилой дом"Пешков"',
#   'objFloorMin': 22,
#   'objFloorMax': 23,
#   'objElemLivingCnt': 273,
#   'objReady100PercDt': '2024-03-31',
#   'objSquareLiving': 12976.29,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 52.5975,
#   'longitude': 39.4902,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 1,
#   'residentialBuildings': 1,
#   'rpdNum': '48-000243',
#   'pdId': 471112,
#   'buildType': 'Жилое',
#   'objStatus': 0},
#  {'objId': 36266,
#   'developer': {'devId': 10215,
#    'shortName': 'СЗ БОЛЬШАЯ ОЧАКОВСКАЯ',
#    'fullName': 'СПЕЦИАЛИЗИРОВАННЫЙ ЗАСТРОЙЩИК БОЛЬШАЯ ОЧАКОВСКАЯ',
#    'groupName': 'ПИК',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'companyGroup': 429726001,
#    'devInn': '9729037439'},
#   'rpdRegionCd': 77,
#   'objAddr': 'г Москва, район Очаково-Матвеевское, ул Очаковская Б., корпус 1',
#   'objCommercNm': 'Жилой комплекс"Большая Очаковская 2"',
#   'objFloorMin': 3,
#   'objFloorMax': 34,
#   'objElemLivingCnt': 1488,
#   'objReady100PercDt': '2022-12-31',
#   'objSquareLiving': 76709.2,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 55.6883,
#   'longitude': 37.467,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 1,
#   'residentialBuildings': 1,
#   'rpdNum': '77-002028',
#   'pdId': 321189,
#   'buildType': 'Жилое',
#   'objStatus': 0},
#  {'objId': 44514,
#   'developer': {'devId': 13439,
#    'shortName': 'СЗ БОЛЬШОЙ ДОМ',
#    'fullName': 'СПЕЦИАЛИЗИРОВАННЫЙ ЗАСТРОЙЩИК БОЛЬШОЙ ДОМ',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'devInn': '3461067027'},
#   'rpdRegionCd': 34,
#   'objAddr': 'г Волгоград, ул Нильская',
#   'objFloorMin': 9,
#   'objFloorMax': 10,
#   'objElemLivingCnt': 143,
#   'objReady100PercDt': '2023-06-30',
#   'objSquareLiving': 7547.14,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 48.7123,
#   'longitude': 44.4824,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 1,
#   'residentialBuildings': 1,
#   'rpdNum': '34-000646',
#   'pdId': 529283,
#   'buildType': 'Жилое',
#   'objStatus': 0},
#  {'objId': 38983,
#   'developer': {'devId': 11145,
#    'shortName': 'СЗ БОНАВА',
#    'fullName': 'СПЕЦИАЛИЗИРОВАННЫЙ ЗАСТРОЙЩИК БОНАВА',
#    'groupName': 'Bonava',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'companyGroup': 2744319001,
#    'devInn': '7841089000'},
#   'rpdRegionCd': 78,
#   'objAddr': 'город Санкт-Петербург, ул Магнитогорская',
#   'objCommercNm': 'Magnifika Lifestyle',
#   'objFloorMin': 15,
#   'objFloorMax': 16,
#   'objElemLivingCnt': 274,
#   'objReady100PercDt': '2023-09-30',
#   'objSquareLiving': 13906.86,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 59.9387,
#   'longitude': 30.4231,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 1,
#   'residentialBuildings': 1,
#   'rpdNum': '78-001655',
#   'pdId': 395099,
#   'buildType': 'Жилое',
#   'objStatus': 0},
#  {'objId': 38802,
#   'developer': {'devId': 11145,
#    'shortName': 'СЗ БОНАВА',
#    'fullName': 'СПЕЦИАЛИЗИРОВАННЫЙ ЗАСТРОЙЩИК БОНАВА',
#    'groupName': 'Bonava',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'companyGroup': 2744319001,
#    'devInn': '7841089000'},
#   'rpdRegionCd': 78,
#   'objAddr': 'ул Магнитогорская, д. 11',
#   'objCommercNm': 'Magnifika Residence',
#   'objFloorMin': 8,
#   'objFloorMax': 15,
#   'objElemLivingCnt': 214,
#   'objReady100PercDt': '2023-12-31',
#   'objSquareLiving': 15139.04,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 59.9362,
#   'longitude': 30.4206,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 1,
#   'residentialBuildings': 1,
#   'rpdNum': '78-001651',
#   'pdId': 394154,
#   'buildType': 'Жилое',
#   'objStatus': 0},
#  {'objId': 44140,
#   'developer': {'devId': 13505,
#    'shortName': 'СЗ БОРИСОВСКИЕ ПРУДЫ',
#    'fullName': 'СПЕЦИАЛИЗИРОВАННЫЙ ЗАСТРОЙЩИК БОРИСОВСКИЕ ПРУДЫ',
#    'groupName': 'ЛСР',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'companyGroup': 429468001,
#    'devInn': '7714983239'},
#   'rpdRegionCd': 77,
#   'objAddr': 'г Москва, район Москворечье-Сабурово, ул Борисовские Пруды',
#   'objCommercNm': 'Жилой комплекс WAVE Жилой комплекс ВЕЙВ',
#   'objFloorMin': 3,
#   'objFloorMax': 54,
#   'objElemLivingCnt': 1482,
#   'objReady100PercDt': '2026-06-30',
#   'objSquareLiving': 75597.8,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 55.6374,
#   'longitude': 37.7073,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 1,
#   'residentialBuildings': 1,
#   'rpdNum': '77-002364',
#   'pdId': 532331,
#   'buildType': 'Жилое',
#   'objStatus': 0},
#  {'objId': 41901,
#   'developer': {'devId': 12764,
#    'shortName': 'СЗ БОШЕСТРОЙИНВЕСТ',
#    'fullName': 'СПЕЦИАЛИЗИРОВАННЫЙ ЗАСТРОЙЩИК БОШЕСТРОЙИНВЕСТ',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'devInn': '3128148408'},
#   'rpdRegionCd': 31,
#   'objAddr': 'г Старый Оскол, мкр Макаренко, д. 41',
#   'objCommercNm': 'БошеСтройИнвест Жизнь в центре города мкр.Макаренко 41',
#   'objFloorMin': 14,
#   'objFloorMax': 14,
#   'objElemLivingCnt': 98,
#   'objReady100PercDt': '2023-09-30',
#   'objSquareLiving': 4023.5,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 51.3143,
#   'longitude': 37.8829,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 1,
#   'residentialBuildings': 1,
#   'rpdNum': '31-000347',
#   'pdId': 482054,
#   'buildType': 'Жилое',
#   'objStatus': 0},
#  {'objId': 41899,
#   'developer': {'devId': 12764,
#    'shortName': 'СЗ БОШЕСТРОЙИНВЕСТ',
#    'fullName': 'СПЕЦИАЛИЗИРОВАННЫЙ ЗАСТРОЙЩИК БОШЕСТРОЙИНВЕСТ',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'devInn': '3128148408'},
#   'rpdRegionCd': 31,
#   'objAddr': 'г Старый Оскол, мкр Макаренко, д. 41',
#   'objFloorMin': 9,
#   'objFloorMax': 9,
#   'objElemLivingCnt': 54,
#   'objReady100PercDt': '2022-12-31',
#   'objSquareLiving': 2049.32,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 51.3146,
#   'longitude': 37.8838,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 1,
#   'residentialBuildings': 1,
#   'rpdNum': '31-000346',
#   'pdId': 471365,
#   'buildType': 'Жилое',
#   'objStatus': 0},
#  {'objId': 41951,
#   'developer': {'devId': 11806,
#    'shortName': 'СЗ БРЕММЕР-ХАУС',
#    'fullName': 'СПЕЦИАЛИЗИРОВАННЫЙ ЗАСТРОЙЩИК БРЕММЕР-ХАУС',
#    'groupName': 'AAG',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'companyGroup': 2497235001,
#    'devInn': '7814690155'},
#   'rpdRegionCd': 78,
#   'objAddr': 'г Санкт-Петербург, линия 12-я В.О., д. 41, литера Ж, корпус 1',
#   'objFloorMin': 7,
#   'objFloorMax': 7,
#   'objElemLivingCnt': 92,
#   'objReady100PercDt': '2024-06-30',
#   'objSquareLiving': 9560.65,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 59.9433,
#   'longitude': 30.2686,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 1,
#   'residentialBuildings': 1,
#   'rpdNum': '78-001778',
#   'pdId': 479994,
#   'buildType': 'Жилое',
#   'objStatus': 0},
#  {'objId': 36437,
#   'developer': {'devId': 10178,
#    'shortName': 'СЗ БРИГ',
#    'fullName': 'СПЕЦИАЛИЗИРОВАННЫЙ ЗАСТРОЙЩИК БРИГ',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'devInn': '6164131571'},
#   'rpdRegionCd': 61,
#   'objAddr': 'г Ростов-на-Дону, улица Береговая, д. 73',
#   'objCommercNm': 'ЖК "Державинский"',
#   'objFloorMin': 25,
#   'objFloorMax': 25,
#   'objElemLivingCnt': 713,
#   'objReady100PercDt': '2022-12-31',
#   'objSquareLiving': 30115.21,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 47.2207,
#   'longitude': 39.746,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 1,
#   'residentialBuildings': 1,
#   'rpdNum': '61-001055',
#   'pdId': 332239,
#   'buildType': 'Жилое',
#   'objStatus': 0},
#  {'objId': 36436,
#   'developer': {'devId': 10178,
#    'shortName': 'СЗ БРИГ',
#    'fullName': 'СПЕЦИАЛИЗИРОВАННЫЙ ЗАСТРОЙЩИК БРИГ',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'devInn': '6164131571'},
#   'rpdRegionCd': 61,
#   'objAddr': 'г Ростов-на-Дону, улица Береговая, д. 73',
#   'objCommercNm': 'ЖК "Державинский"',
#   'objFloorMin': 25,
#   'objFloorMax': 25,
#   'objElemLivingCnt': 598,
#   'objReady100PercDt': '2022-12-31',
#   'objSquareLiving': 27741.97,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 47.2206,
#   'longitude': 39.7447,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 1,
#   'residentialBuildings': 1,
#   'rpdNum': '61-001055',
#   'pdId': 332239,
#   'buildType': 'Жилое',
#   'objStatus': 0},
#  {'objId': 42704,
#   'developer': {'devId': 13123,
#    'shortName': 'СЗ БРИЗ',
#    'fullName': 'СПЕЦИАЛИЗИРОВАННЫЙ ЗАСТРОЙЩИК БРИЗ',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'devInn': '2130223241'},
#   'rpdRegionCd': 21,
#   'objAddr': 'г Чебоксары, район Новоюжный',
#   'objFloorMin': 11,
#   'objFloorMax': 11,
#   'objElemLivingCnt': 434,
#   'objReady100PercDt': '2023-06-30',
#   'objSquareLiving': 20403.74,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 56.1438,
#   'longitude': 47.2489,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 1,
#   'residentialBuildings': 1,
#   'rpdNum': '21-000487',
#   'pdId': 503622,
#   'buildType': 'Жилое',
#   'objStatus': 0},
#  {'objId': 37861,
#   'developer': {'devId': 9401,
#    'shortName': 'СЗ БРИК',
#    'fullName': 'СПЕЦИАЛИЗИРОВАННЫЙ ЗАСТРОЙЩИК БРИК',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'devInn': '3102046793'},
#   'rpdRegionCd': 31,
#   'objAddr': 'пгт Северный, микрорайон Центральный',
#   'objCommercNm': 'Жилой квартал Браер Парк Центр',
#   'objFloorMin': 5,
#   'objFloorMax': 5,
#   'objElemLivingCnt': 79,
#   'objReady100PercDt': '2022-09-30',
#   'objSquareLiving': 4400.64,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 50.6782,
#   'longitude': 36.5738,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 1,
#   'residentialBuildings': 1,
#   'rpdNum': '31-000299',
#   'pdId': 378943,
#   'buildType': 'Жилое',
#   'objStatus': 0},
#  {'objId': 37858,
#   'developer': {'devId': 9401,
#    'shortName': 'СЗ БРИК',
#    'fullName': 'СПЕЦИАЛИЗИРОВАННЫЙ ЗАСТРОЙЩИК БРИК',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'devInn': '3102046793'},
#   'rpdRegionCd': 31,
#   'objAddr': 'пгт Северный, микрорайон Центральный',
#   'objCommercNm': 'Жилой квартал Браер Парк Центр',
#   'objFloorMin': 5,
#   'objFloorMax': 5,
#   'objElemLivingCnt': 158,
#   'objReady100PercDt': '2023-06-30',
#   'objSquareLiving': 9196.59,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 50.6782,
#   'longitude': 36.5738,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 1,
#   'residentialBuildings': 1,
#   'rpdNum': '31-000297',
#   'pdId': 380929,
#   'buildType': 'Жилое',
#   'objStatus': 0},
#  {'objId': 37857,
#   'developer': {'devId': 9401,
#    'shortName': 'СЗ БРИК',
#    'fullName': 'СПЕЦИАЛИЗИРОВАННЫЙ ЗАСТРОЙЩИК БРИК',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'devInn': '3102046793'},
#   'rpdRegionCd': 31,
#   'objAddr': 'пгт Северный, микрорайон Центральный',
#   'objCommercNm': 'Жилой квартал Браер Парк Центр',
#   'objFloorMin': 5,
#   'objFloorMax': 5,
#   'objElemLivingCnt': 101,
#   'objReady100PercDt': '2022-12-31',
#   'objSquareLiving': 5501.36,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 50.6782,
#   'longitude': 36.5738,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 1,
#   'residentialBuildings': 1,
#   'rpdNum': '31-000298',
#   'pdId': 380828,
#   'buildType': 'Жилое',
#   'objStatus': 0},
#  {'objId': 41405,
#   'developer': {'devId': 11112,
#    'shortName': 'СЗ БРИК-ПАРК',
#    'fullName': 'СПЕЦИАЛИЗИРОВАННЫЙ ЗАСТРОЙЩИК БРИК-ПАРК',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'devInn': '3102046786'},
#   'rpdRegionCd': 31,
#   'objAddr': 'с Стрелецкое',
#   'objCommercNm': 'Жилой комплекс"Московский квартал"',
#   'objFloorMin': 4,
#   'objFloorMax': 4,
#   'objElemLivingCnt': 22,
#   'objReady100PercDt': '2023-06-30',
#   'objSquareLiving': 1136.96,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 50.7004,
#   'longitude': 36.4845,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 1,
#   'residentialBuildings': 1,
#   'rpdNum': '31-000339',
#   'pdId': 473624,
#   'buildType': 'Жилое',
#   'objStatus': 0},
#  {'objId': 41285,
#   'developer': {'devId': 11112,
#    'shortName': 'СЗ БРИК-ПАРК',
#    'fullName': 'СПЕЦИАЛИЗИРОВАННЫЙ ЗАСТРОЙЩИК БРИК-ПАРК',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'devInn': '3102046786'},
#   'rpdRegionCd': 31,
#   'objAddr': 'с Стрелецкое',
#   'objCommercNm': 'Жилой комплекс"Московский квартал"',
#   'objFloorMin': 4,
#   'objFloorMax': 4,
#   'objElemLivingCnt': 23,
#   'objReady100PercDt': '2023-06-30',
#   'objSquareLiving': 1147.8,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 50.7001,
#   'longitude': 36.4841,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 1,
#   'residentialBuildings': 1,
#   'rpdNum': '31-000338',
#   'pdId': 473666,
#   'buildType': 'Жилое',
#   'objStatus': 0},
#  {'objId': 41265,
#   'developer': {'devId': 11112,
#    'shortName': 'СЗ БРИК-ПАРК',
#    'fullName': 'СПЕЦИАЛИЗИРОВАННЫЙ ЗАСТРОЙЩИК БРИК-ПАРК',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'devInn': '3102046786'},
#   'rpdRegionCd': 31,
#   'objAddr': 'с Стрелецкое',
#   'objCommercNm': 'Жилой комплекс"Московский квартал"',
#   'objFloorMin': 4,
#   'objFloorMax': 4,
#   'objElemLivingCnt': 23,
#   'objReady100PercDt': '2023-06-30',
#   'objSquareLiving': 1147.8,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 50.7004,
#   'longitude': 36.4855,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 1,
#   'residentialBuildings': 1,
#   'rpdNum': '31-000337',
#   'pdId': 473679,
#   'buildType': 'Жилое',
#   'objStatus': 0},
#  {'objId': 42121,
#   'developer': {'devId': 11112,
#    'shortName': 'СЗ БРИК-ПАРК',
#    'fullName': 'СПЕЦИАЛИЗИРОВАННЫЙ ЗАСТРОЙЩИК БРИК-ПАРК',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'devInn': '3102046786'},
#   'rpdRegionCd': 31,
#   'objAddr': 'с Стрелецкое',
#   'objCommercNm': 'Жилой комплекс"Московский квартал"',
#   'objFloorMin': 4,
#   'objFloorMax': 4,
#   'objElemLivingCnt': 23,
#   'objReady100PercDt': '2023-06-30',
#   'objSquareLiving': 1147.8,
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'latitude': 50.7005,
#   'longitude': 36.4861,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 1,
#   'residentialBuildings': 1,
#   'rpdNum': '31-000354',
#   'pdId': 483958,
#   'buildType': 'Жилое',
#   'objStatus': 0}]

# %%
objects_list = objects_data.get('data').get('list')

# %%
objids = [x.get('objId') for x in objects_list]

# %%
len(objids)
# Out:
# 8092

# %%
objids[:10]
# Out:
# [36774, 5208, 5207, 5206, 28951, 16849, 16847, 16850, 16851, 13038]

# %% [markdown]
# # Данные по определенному объекту

# %%
url = f'https://xn--80az8a.xn--d1aqf.xn--p1ai/%D1%81%D0%B5%D1%80%D0%B2%D0%B8%D1%81%D1%8B/api/object/36774'

# %%
res = requests.get(url)
res.json()
# Out:
# {'data': {'id': 36774,
#   'pdId': 351714,
#   'developer': {'devId': 6926,
#    'devShortCleanNm': 'ОКЕАН',
#    'devShortNm': 'ОКЕАН',
#    'devFullCleanNm': 'ОКЕАН',
#    'problObjCnt': 0,
#    'buildObjCnt': 1,
#    'comissObjCnt': 0,
#    'regRegionDesc': 'Башкортостан Республика',
#    'devPhoneNum': '+7(927)300-31-01',
#    'devSite': 'altun-yar.ru',
#    'devEmail': 'khabibovr@mail.ru',
#    'devInn': '0277093608',
#    'devOgrn': '1080277004521',
#    'devKpp': '027701001',
#    'devLegalAddr': 'Башкортостан Республика, город Уфа, проспект Проспект Октября дом 85',
#    'devFactAddr': 'Респ Башкортостан Город Уфа Проспект Октября д. 85',
#    'lastRpdId': 511041,
#    'fundGuarantyFlg': 0,
#    'devOrgRegRegionCd': 2,
#    'devEmplMainFullNm': 'Хабибов Рамиль Хамидуллович',
#    'developerGroupName': 'Океан',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'companyGroupId': 5767476001,
#    'objGuarantyEscrowFlg': 1,
#    'govFundFlg': 0},
#   'region': 2,
#   'address': 'г Уфа, ул Прибельская, д. 32, 32/1, 34',
#   'floorMin': 5,
#   'floorMax': 9,
#   'objElemLivingCnt': 0,
#   'objReady100PercDt': '2024-09-30',
#   'wallMaterialShortDesc': 'Монолит-кирпич',
#   'objLkFinishTypeDesc': 'Без отделки',
#   'objLkFreePlanDesc': 'Есть',
#   'objElemParkingCnt': 73,
#   'objSquareLiving': 0.0,
#   'rpdNum': '02-001200',
#   'rpdPdfLink': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/8455bc4e-fc18-46c6-b684-f86c7fe3da85',
#   'rpdIssueDttm': '07-10-2021 09:15',
#   'objLkLatitude': '54.6871',
#   'objLkLongitude': '55.9563',
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'objLkClassDesc': 'Типовой',
#   'loadDttm': '27-01-2022 01:10',
#   'photoRenderDTO': [{'objId': 36774,
#     'pdId': 351714,
#     'rpdId': 511041,
#     'devId': 6926,
#     'ordNum': 1,
#     'objRenderPhotoSize': 406650,
#     'objRenderPhotoUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/7d361bd3-f91d-47ac-a468-19ba445ce116',
#     'objRenderPhotoDttm': '25-08-2020 12:17',
#     'objRenderPhotoHiddenFlg': 0,
#     'objRenderPhotoNm': '1.jpg',
#     'objReadyDesc': 'Строится',
#     'objBuildTypeShortDesc': 'Нежилое',
#     'knFlg': 0,
#     'loadDttm': '27-01-2022 00:56'},
#    {'objId': 36774,
#     'pdId': 351714,
#     'rpdId': 511041,
#     'devId': 6926,
#     'ordNum': 2,
#     'objRenderPhotoSize': 474129,
#     'objRenderPhotoUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/f4cd2621-6ed8-42c6-a864-105d08dc8fed',
#     'objRenderPhotoDttm': '25-08-2020 12:17',
#     'objRenderPhotoHiddenFlg': 0,
#     'objRenderPhotoNm': '21.jpg',
#     'objReadyDesc': 'Строится',
#     'objBuildTypeShortDesc': 'Нежилое',
#     'knFlg': 0,
#     'loadDttm': '27-01-2022 00:56'}],
#   'objGuarantyEscrowFlg': 1,
#   'objectType': 'normal',
#   'miniUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/882375c0-5d57-471d-9998-2ea99f0d81d9',
#   'residentialBuildings': 0,
#   'newBuildingId': 117025,
#   'objFloorCnt': 9,
#   'objFlatCnt': 0,
#   'objFlatSq': '0.0',
#   'objNonlivElemCnt': 173,
#   'objStatus': 0,
#   'isAvailableWantLiveHere': True,
#   'objTransferPlanDt': '31-08-2024 12:00',
#   'objInfrstrBicycleLaneFlg': 0,
#   'objInfrstrPlaygrndCnt': 0,
#   'objInfrstrSportGroundCnt': 0,
#   'objInfrstrTrashAreaCnt': 0,
#   'objInfrstrObjPrkngCnt': 0,
#   'objInfrstrNotObjPrkngCnt': 0,
#   'objInfrstrRampFlg': 0,
#   'objInfrstrCurbLoweringFlg': 0,
#   'objElevatorWheelchairCnt': 0,
#   'objElevatorPassengerCnt': 5,
#   'objElevatorCargoCnt': 0,
#   'soldOutPerc': 1.0,
#   'objPriceAvg': 45187,
#   'generalContractorNm': 'ООО НЕРУД ИНВЕСТ (ИНН: 0277077148)',
#   'nonlivFirstFloor': 1,
#   'objectTransportInfo': [],
#   'conclusion': False,
#   'objLkSaleDepEmail': 'khabibovr@mail.ru',
#   'objGreenHouseFlg': 0,
#   'objEnergyEffShortDesc': 'C'},
#  'errcode': '0'}

# %%
import pandas as pd

# %%
# Out:
#   errcode  data.id  data.pdId  data.developer.devId  \
# 0       0    36774     351714                  6926
#
#   data.developer.devShortCleanNm data.developer.devShortNm  \
# 0                          ОКЕАН                     ОКЕАН
#
#   data.developer.devFullCleanNm  data.developer.problObjCnt  \
# 0                         ОКЕАН                           0
#
#    data.developer.buildObjCnt  data.developer.comissObjCnt  ...  \
# 0                           1                            0  ...
#
#   data.objElevatorCargoCnt data.soldOutPerc data.objPriceAvg  \
# 0                        0              1.0            45187
#
#              data.generalContractorNm data.nonlivFirstFloor  \
# 0  ООО НЕРУД ИНВЕСТ (ИНН: 0277077148)                     1
#
#   data.objectTransportInfo data.conclusion data.objLkSaleDepEmail  \
# 0                       []           False      khabibovr@mail.ru
#
#   data.objGreenHouseFlg  data.objEnergyEffShortDesc
# 0                     0                           C
#
# [1 rows x 83 columns]
