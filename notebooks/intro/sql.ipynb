# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ds-reboot/python-first-part/blob/main/notebooks/intro/sql.ipynb)

# %%
import pandas as pd
import sqlite3

conn = sqlite3.connect('test_database')

# %%
data = {
        'product_name': ['Computer','Tablet','Monitor','Printer'],
        'price': [900,300,450,150]
        }

df = pd.DataFrame(data)

# %%
df
# Out:
#   product_name  price
# 0     Computer    900
# 1       Tablet    300
# 2      Monitor    450
# 3      Printer    150

# %%
df.to_sql('products', conn, if_exists='replace', index = False)
conn.commit()
conn.close()

# %%
df.to_csv('products.csv')

# %%
df.to_excel('products.xlsx')

# %%
# !pip install openpyxl
# Out:
# ...
#   Using cached openpyxl-3.0.10-py2.py3-none-any.whl (242 kB)
# ...
#   Using cached et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# ...
# WARNING: You are using pip version 21.3.1; however, version 22.2.2 is available.
# You should consider upgrading via the '/Users/lev4/Projects/reboot/DS2022_3/ds_project/venv/bin/python -m pip install --upgrade pip' command.

# %%
df.to_pickle('products.pkl')
